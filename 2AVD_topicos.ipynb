# %%
# REQUISITO DA PROVA:
# 1) Desenvolva um código que lhe permita abrir uma imagem RGB ou BGR de sua preferência, utilizando a interface python do OpenCV.

# %%
#Craindo os imports
from PIL import Image
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
#import dlib
import dlib

# %%
#Leituras das imagem RGB ou BGR
imagem = cv2.imread('/content/rostos-confianca.jpg')
#Carregando o modelo de detecção de faces
detector_de_face = dlib.get_frontal_face_detector()
deteccoes_face = detector_de_face(imagem, 1)
#Desenhando os retangulos (caixa envolvente)
for face in deteccoes_face:
  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(imagem, (l, t), (r, b), (0,255,255), 2)
#Exibindo as imagem com os retangulos
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F1110A0CD90>

# %%
#Carregar o detector de marcos faciais da dlib:
detector_pontos_faciais = dlib.shape_predictor('/content/shape_predictor_68_face_landmarks.dat')
#Encontrando os marcos faciais de cada uma das faces
for face in deteccoes_face:
  pontos_face = detector_pontos_faciais(imagem, face)
#Desenhando os marcos faciais na imagem
  for ponto in pontos_face.parts():
    cv2.circle(imagem, (ponto.x, ponto.y), 2, (0,255,0), 1)
#Desenhando os retangulos na imagem (caixa envolvente)
  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(imagem, (l, t), (r, b), (0,255,255), 2)
#Mostrando a imagem
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F11109B2F50>
